# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#!pip install plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import datetime as dt
from datetime import timedelta
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,silhouette_samples
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score
import statsmodels.api as sm
from statsmodels.tsa.api import Holt,SimpleExpSmoothing,ExponentialSmoothing
from fbprophet import Prophet
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.tsa.stattools import adfuller
# !pip install pmdarima
from pmdarima import auto_arima
std=StandardScaler()
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 24.5 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 55.1 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-af53881e-14c3-4bef-bbff-62874598039d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af53881e-14c3-4bef-bbff-62874598039d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving countries-aggregated.csv to countries-aggregated.csv

# %%
covid=pd.read_csv(r'countries-aggregated.csv')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
covid.tail()
# Out:
#              Date   Country  Confirmed  Recovered  Deaths
# 91387  2021-05-07  Zimbabwe      38403      36041    1576
# 91388  2021-05-08  Zimbabwe      38414      36052    1576
# 91389  2021-05-09  Zimbabwe      38419      36063    1576
# 91390  2021-05-10  Zimbabwe      38433      36208    1576
# 91391  2021-05-11  Zimbabwe      38448      36221    1579

# %%
covid.shape
# Out:
# (91392, 5)

# %%
covid.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91392 entries, 0 to 91391
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       91392 non-null  object
#  1   Country    91392 non-null  object
#  2   Confirmed  91392 non-null  int64
#  3   Recovered  91392 non-null  int64
#  4   Deaths     91392 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 3.5+ MB

# %%
covid['Date']=pd.to_datetime(covid['Date'])

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91392 entries, 0 to 91391
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       91392 non-null  datetime64[ns]
#  1   Country    91392 non-null  object
#  2   Confirmed  91392 non-null  int64
#  3   Recovered  91392 non-null  int64
#  4   Deaths     91392 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 3.5+ MB

# %%
covid.head(1)
# Out:
#         Date      Country  Confirmed  Recovered  Deaths
# 0 2020-01-22  Afghanistan          0          0       0

# %%
covid['Active']=covid['Confirmed']-covid['Recovered']-covid['Deaths']

# %%
groupby_country=covid.groupby(['Country','Date']).agg({'Confirmed':'sum','Recovered':'sum','Deaths':'sum','Active':'sum'})
groupby_datewise=covid.groupby(['Date']).agg({'Confirmed':'sum','Recovered':'sum','Deaths':'sum','Active':'sum'})

# %%
covid['Active']=covid['Confirmed']-covid['Recovered']-covid['Deaths']

# %%
covid.tail()
# Out:
#             Date   Country  Confirmed  Recovered  Deaths  Active
# 91387 2021-05-07  Zimbabwe      38403      36041    1576     786
# 91388 2021-05-08  Zimbabwe      38414      36052    1576     786
# 91389 2021-05-09  Zimbabwe      38419      36063    1576     780
# 91390 2021-05-10  Zimbabwe      38433      36208    1576     649
# 91391 2021-05-11  Zimbabwe      38448      36221    1579     648

# %%
print("Totol number of countries with Disease Spread: ",len(covid["Country"].unique()))
# Out:
# Totol number of countries with Disease Spread:  192

# %%
print("total number of confirmed cases around the world",groupby_datewise['Confirmed'].iloc[-1])
print("total number of Recovered cases around the world",groupby_datewise['Recovered'].iloc[-1])
print("total number of Deaths cases around the world",groupby_datewise['Deaths'].iloc[-1])
print("total number of Active cases around the world",groupby_datewise['Active'].iloc[-1])
print("Approximate number of Confirmed Cases per Day around the World: ",np.round(groupby_datewise["Confirmed"].iloc[-1]/groupby_datewise.shape[0]))
print("Approximate number of Recovered Cases per Day around the World: ",np.round(groupby_datewise["Recovered"].iloc[-1]/groupby_datewise.shape[0]))
print("Approximate number of Deaths Cases per Day around the World: ",np.round(groupby_datewise["Deaths"].iloc[-1]/groupby_datewise.shape[0]))
print("Approximate number of Active Cases per Day around the World: ",np.round(groupby_datewise["Active"].iloc[-1]/groupby_datewise.shape[0]))
# Out:
# total number of confirmed cases around the world 159338940
# total number of Recovered cases around the world 95390977
# total number of Deaths cases around the world 3313013
# total number of Active cases around the world 60634950
# Approximate number of Confirmed Cases per Day around the World:  334746.0
# Approximate number of Recovered Cases per Day around the World:  200401.0
# Approximate number of Deaths Cases per Day around the World:  6960.0
# Approximate number of Active Cases per Day around the World:  127384.0

# %%
groupby_datewise.shape
# Out:
# (476, 4)

# %%
fig=px.bar(x=groupby_datewise.index,y=groupby_datewise["Active"])
fig.update_layout(title="Distribution of Number of Active Cases",
                  xaxis_title="Date",yaxis_title="Number of Cases",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8070b362-c7b4-4c5e-9f84-85a931597832" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8070b362-c7b4-4c5e-9f84-85a931597832")) {
#                     Plotly.newPlot(
#                         '8070b362-c7b4-4c5e-9f84-85a931597832',
# ...

# %% [markdown]
# Growth rate of Active case

# %%
fig=px.bar(x=groupby_datewise.index,y=groupby_datewise["Active"])
fig.update_layout(title="Distribution of Number of Active Cases",
                  xaxis_title="Date",yaxis_title="Number of Cases",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f28ffc2f-853e-46d5-9b60-5e489ff7f166" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f28ffc2f-853e-46d5-9b60-5e489ff7f166")) {
#                     Plotly.newPlot(
#                         'f28ffc2f-853e-46d5-9b60-5e489ff7f166',
# ...

# %%
fig=px.bar(x=groupby_datewise.index,y=groupby_datewise["Confirmed"])
fig.update_layout(title="Distribution of Number of Confirmed Cases",
                  xaxis_title="Date",yaxis_title="Number of Confirmed Cases",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d747df2c-8122-4d97-8d13-4f9800db4bb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d747df2c-8122-4d97-8d13-4f9800db4bb9")) {
#                     Plotly.newPlot(
#                         'd747df2c-8122-4d97-8d13-4f9800db4bb9',
# ...

# %%
fig=px.bar(x=groupby_datewise.index,y=groupby_datewise["Recovered"])
fig.update_layout(title="Distribution of Number of Active Cases",
                  xaxis_title="Date",yaxis_title="Number of Cases",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0668f225-8282-4689-9c6a-a3e6582c8575" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0668f225-8282-4689-9c6a-a3e6582c8575")) {
#                     Plotly.newPlot(
#                         '0668f225-8282-4689-9c6a-a3e6582c8575',
# ...

# %%
fig=px.bar(x=groupby_datewise.index,y=groupby_datewise["Deaths"])
fig.update_layout(title="Distribution of Deaths Cases",
                  xaxis_title="Date",yaxis_title="Number of Deaths",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e20bbf14-877d-4ba0-9a7c-d5d7bde1173b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e20bbf14-877d-4ba0-9a7c-d5d7bde1173b")) {
#                     Plotly.newPlot(
#                         'e20bbf14-877d-4ba0-9a7c-d5d7bde1173b',
# ...

# %% [markdown]
# Growth rate of Confirmed, Recovered and Death Cases

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Confirmed"],
                    mode='lines+markers',
                    name='Confirmed Cases'))
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Recovered"],
                    mode='lines+markers',
                    name='Recovered Cases'))
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Deaths"],
                    mode='lines+markers',
                    name='Death Cases'))
fig.update_layout(title="Growth of different types of cases",
                 xaxis_title="Date",yaxis_title="Number of Cases",legend=dict(x=0,y=1,traceorder="normal"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b8a281b0-67a3-49fb-9473-91b426360d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b8a281b0-67a3-49fb-9473-91b426360d35")) {
#                     Plotly.newPlot(
#                         'b8a281b0-67a3-49fb-9473-91b426360d35',
# ...

# %%
groupby_datewise["Mortality Rate"]=(groupby_datewise["Deaths"]/groupby_datewise["Confirmed"])*100
groupby_datewise["Recovery Rate"]=(groupby_datewise["Recovered"]/groupby_datewise["Confirmed"])*100

print("Average Mortality Rate",groupby_datewise["Mortality Rate"].mean())
print("Median Mortality Rate",groupby_datewise["Mortality Rate"].median())
print("Average Recovery Rate",groupby_datewise["Recovery Rate"].mean())
print("Median Recovery Rate",groupby_datewise["Recovery Rate"].median())

fig = make_subplots(rows=2, cols=1,
                   subplot_titles=("Recovery Rate", "Mortatlity Rate"))
fig.add_trace(
    go.Scatter(x=groupby_datewise.index, y=(groupby_datewise["Recovered"]/groupby_datewise["Confirmed"])*100,name="Recovery Rate"),
    row=1, col=1
)
fig.add_trace(
    go.Scatter(x=groupby_datewise.index, y=(groupby_datewise["Deaths"]/groupby_datewise["Confirmed"])*100,name="Mortality Rate"),
    row=2, col=1
)
fig.update_layout(height=1000,legend=dict(x=-0.1,y=1.2,traceorder="normal"))
fig.update_xaxes(title_text="Date", row=1, col=1)
fig.update_yaxes(title_text="Recovery Rate", row=1, col=1)
fig.update_xaxes(title_text="Date", row=1, col=2)
fig.update_yaxes(title_text="Mortality Rate", row=1, col=2)
fig.show()
# Out:
# Average Mortality Rate 3.4643634486024704
# Median Mortality Rate 2.852298489224718
# Average Recovery Rate 50.69759709413297
# Median Recovery Rate 56.38126679466767
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="46e7193c-6f35-4f73-944a-47665073c82f" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46e7193c-6f35-4f73-944a-47665073c82f")) {
# ...

# %%
print("Average growth factor of number of Confirmed Cases: ",(groupby_datewise["Confirmed"]/groupby_datewise["Confirmed"].shift()).mean())
print("Median growth factor of number of Confirmed Cases: ",(groupby_datewise["Confirmed"]/groupby_datewise["Confirmed"].shift()).median())
print("Average growth factor of number of Recovered Cases: ",(groupby_datewise["Recovered"]/groupby_datewise["Recovered"].shift()).mean())
print("Median growth factor of number of Recovered Cases: ",(groupby_datewise["Recovered"]/groupby_datewise["Recovered"].shift()).median())
print("Average growth factor of number of Death Cases: ",(groupby_datewise["Deaths"]/groupby_datewise["Deaths"].shift()).mean())
print("Median growth factor of number of Death Cases: ",(groupby_datewise["Deaths"]/groupby_datewise["Deaths"].shift()).median())

fig=go.Figure()
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Confirmed"]/groupby_datewise["Confirmed"].shift(),
                    mode='lines',
                    name='Growth Factor of Confirmed Cases'))
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Recovered"]/groupby_datewise["Recovered"].shift(),
                    mode='lines',
                    name='Growth Factor of Recovered Cases'))
fig.add_trace(go.Scatter(x=groupby_datewise.index, y=groupby_datewise["Deaths"]/groupby_datewise["Deaths"].shift(),
                    mode='lines',
                    name='Growth Factor of Death Cases'))
fig.update_layout(title="Datewise Growth Factor of different types of cases",
                 xaxis_title="Date",yaxis_title="Growth Factor",
                 legend=dict(x=0,y=-0.4,traceorder="normal"))
fig.show()
# Out:
# Average growth factor of number of Confirmed Cases:  1.0286351151202853
# Median growth factor of number of Confirmed Cases:  1.0107858395915743
# Average growth factor of number of Recovered Cases:  1.0340525356464947
# Median growth factor of number of Recovered Cases:  1.0115859383369592
# Average growth factor of number of Death Cases:  1.0276646600242423
# Median growth factor of number of Death Cases:  1.0075485799327673
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
# ...

# %% [markdown]
# Countrywise Analysis

# %%
countrywise=covid[covid["Date"]==covid["Date"].max()].groupby(["Country"]).agg({"Confirmed":'sum',"Recovered":'sum',"Deaths":'sum','Active':'sum'}).sort_values(["Confirmed"],ascending=False)
countrywise["Mortality"]=(countrywise["Deaths"]/countrywise["Confirmed"])*100
countrywise["Recovery"]=(countrywise["Recovered"]/countrywise["Confirmed"])*100
countrywise['Active']=countrywise['Confirmed']-countrywise['Recovered']-countrywise['Deaths']

# %%
plt.figure(figsize=(15,7))
plt.axes(axisbelow=True)
plt.barh(countrywise.sort_values('Confirmed')["Confirmed"].index[-10:],countrywise.sort_values('Confirmed')["Confirmed"].values[-10:])
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Confirmed Cases",fontsize=18)
plt.title("Top 10 Countries (Confirmed Cases)",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 10 Countries (Confirmed Cases)')

# %%
plt.figure(figsize=(15,7))
plt.axes(axisbelow=True)
plt.barh(countrywise.sort_values('Deaths')["Deaths"].index[-10:],countrywise.sort_values('Deaths')["Deaths"].values[-10:])
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Mortality Cases",fontsize=18)
plt.title("Top 10 Countries (Mortality Cases)",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 10 Countries (Mortality Cases)')

# %%
plt.figure(figsize=(15,7))
plt.axes(axisbelow=True)
plt.barh(countrywise.sort_values('Active')["Active"].index[-10:],countrywise.sort_values('Active')["Active"].values[-10:])
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Active Cases",fontsize=18)
plt.title("Top 10 Countries (Active Cases)",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 10 Countries (Active Cases)')

# %%
plt.figure(figsize=(15,7))
plt.axes(axisbelow=True)
plt.barh(countrywise.sort_values('Recovered')["Recovered"].index[-10:],countrywise.sort_values('Recovered')["Recovered"].values[-10:])
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Recovered Cases",fontsize=18)
plt.title("Top 10 Countries (Recovered Cases)",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 10 Countries (Recovered Cases)')

# %% [markdown]
# Modelling

# %%
model_train=groupby_datewise.iloc[:int(groupby_datewise.shape[0]*0.95)]
valid=groupby_datewise.iloc[int(groupby_datewise.shape[0]*0.95):]
y_pred=valid.copy()

# %%
model_arima= auto_arima(model_train["Confirmed"],trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,
                   suppress_warnings=True,stepwise=False,seasonal=False)
model_arima.fit(model_train["Confirmed"])
# Out:
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=11367.701, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=11339.068, Time=0.18 sec
#  ARIMA(0,2,2)(0,0,0)[0] intercept   : AIC=11298.328, Time=0.27 sec
#  ARIMA(0,2,3)(0,0,0)[0] intercept   : AIC=11291.500, Time=0.38 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=11354.610, Time=0.05 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=11291.594, Time=0.27 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=11309.458, Time=0.45 sec
#  ARIMA(1,2,3)(0,0,0)[0] intercept   : AIC=11381.882, Time=0.90 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=11354.774, Time=0.09 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=11280.122, Time=0.71 sec
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.28 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=11129.389, Time=0.96 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=11311.974, Time=0.13 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=11220.960, Time=0.24 sec
# ...

# %%
prediction_arima=model_arima.predict(len(valid))
y_pred["ARIMA Model Prediction"]=prediction_arima

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=model_train.index, y=model_train["Confirmed"],
                    mode='lines+markers',name="Train Data for Confirmed Cases"))
fig.add_trace(go.Scatter(x=valid.index, y=valid["Confirmed"],
                    mode='lines+markers',name="Validation Data for Confirmed Cases",))
fig.add_trace(go.Scatter(x=valid.index, y=y_pred["ARIMA Model Prediction"],
                    mode='lines+markers',name="Prediction for Confirmed Cases",))
fig.update_layout(title="Confirmed Cases ARIMA Model Prediction",
                 xaxis_title="Date",yaxis_title="Confirmed Cases",legend=dict(x=0,y=1,traceorder="normal"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f751fb45-e858-448b-b4fa-483bfa7d73ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f751fb45-e858-448b-b4fa-483bfa7d73ee")) {
#                     Plotly.newPlot(
#                         'f751fb45-e858-448b-b4fa-483bfa7d73ee',
# ...
